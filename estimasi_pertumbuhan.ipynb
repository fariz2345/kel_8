# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('estimasi_pertumbuhan.csv')

# %%
df.head()
# Out:
#    temperatur_udara  kelembapan  curah_hujan  suhu_air  panjang_ikan  \
# 0              21.5        86.0         83.1      28.4          80.1
# 1              25.1        73.4         95.1      25.5          71.7
# 2              29.0        85.7         10.1      29.3          99.1
# 3              25.4        52.3         61.4      27.5          94.5
# 4              28.3        84.0         48.8      27.8          93.3
#
#    berat_ikan
# 0         9.1
# 1         5.3
# 2         9.4
# 3         6.0
# 4         3.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   temperatur_udara  1000 non-null   float64
#  1   kelembapan        1000 non-null   float64
#  2   curah_hujan       1000 non-null   float64
#  3   suhu_air          1000 non-null   float64
#  4   panjang_ikan      1000 non-null   float64
#  5   berat_ikan        1000 non-null   float64
# dtypes: float64(6)
# memory usage: 47.0 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        temperatur_udara   kelembapan  curah_hujan     suhu_air  panjang_ikan  \
# count       1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean          27.561200    74.817200    49.088300    25.003700     55.735900
# std            4.233913    14.457535    28.903924     2.914734     25.796487
# min           20.000000    50.000000     0.300000    20.000000     10.100000
# 25%           24.000000    62.400000    24.375000    22.500000     34.100000
# 50%           27.400000    74.650000    47.900000    25.050000     55.800000
# 75%           31.100000    86.900000    73.675000    27.500000     78.425000
# max           35.000000   100.000000    99.400000    30.000000    100.000000
#
#         berat_ikan
# count  1000.000000
# mean      5.039100
# std       2.846683
# min       0.100000
# 25%       2.500000
# 50%       5.100000
# 75%       7.500000
# max      10.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
features = ['temperatur_udara','kelembapan','curah_hujan','suhu_air']
targett = ['panjang_ikan','berat_ikan']
x = df[features]
y = df[targett]
x.shape, y.shape
# Out:
# ((1000, 4), (1000, 2))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=70)
y_test.shape
# Out:
# (250, 2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)

# %%
score = lr.score(x_test,y_test)
print('akurasi model regresi linear = ', score)
# Out:
# akurasi model regresi linear =  -0.012433207478082076

# %%
input_data = np.array([[21.5,86.0,83.1,28.4]])

prediction = lr.predict(input_data)
print('estimasi panjang dan berat ikan :', prediction)
# Out:
# estimasi panjang dan berat ikan : [[54.31220879  5.01801962]]
# C:\Users\kusum\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
